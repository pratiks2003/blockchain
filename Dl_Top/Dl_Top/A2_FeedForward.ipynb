# %%
#--Assignment 2--

# Implementing Feedforward neural networks with Keras and TensorFlow
# a. Import the necessary packages
# b. Load the training and testing data (MNIST/CIFAR10)
# c. Define the network architecture using Keras
# d. Train the model using SGD
# e. Evaluate the network
# f. Plot the training loss and accuracy

# %%
# Step 1: Import necessary packages
import numpy as np
import tensorflow as tf
from keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
import matplotlib.pyplot as plt

# %%
# Step 2: Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# One-hot encode the labels
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 5s 0us/step

# %%
# Step 3: Define the network architecture
model = Sequential([
    Flatten(input_shape=(32, 32, 3)),  # Adjust input shape for CIFAR-10
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# %%
# Step 4: Compile the model
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Step 5: Train the model
history = model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.9349 - accuracy: 0.3025 - val_loss: 1.8860 - val_accuracy: 0.3350
# Epoch 2/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.7598 - accuracy: 0.3711 - val_loss: 1.7217 - val_accuracy: 0.3913
# Epoch 3/10
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6822 - accuracy: 0.4012 - val_loss: 1.6973 - val_accuracy: 0.3987
# Epoch 4/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.6324 - accuracy: 0.4220 - val_loss: 1.6853 - val_accuracy: 0.4065
# Epoch 5/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.5919 - accuracy: 0.4366 - val_loss: 1.5956 - val_accuracy: 0.4266
# Epoch 6/10
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.5616 - accuracy: 0.4469 - val_loss: 1.5590 - val_accuracy: 0.4485
# Epoch 7/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.5323 - accuracy: 0.4579 - val_loss: 1.5665 - val_accuracy: 0.4399
# Epoch 8/10
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.5063 - accuracy: 0.4638 - val_loss: 1.5324 - val_accuracy: 0.4508
# Epoch 9/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.4868 - accuracy: 0.4737 - val_loss: 1.6114 - val_accuracy: 0.4269
# Epoch 10/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.4705 - accuracy: 0.4784 - val_loss: 1.5025 - val_accuracy: 0.4715

# %%
# Step 6: Evaluate the network
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy*100:.2f}%')
# Out:
# Test accuracy: 47.15%

# %%
# Step 7: Plot the training loss and accuracy
plt.figure(figsize=(10, 4))

# %%
# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# %%
# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# %%
plt.tight_layout()
plt.show()
